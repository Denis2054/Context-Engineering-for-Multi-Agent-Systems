# %% [markdown]
# <a href="https://colab.research.google.com/github/Denis2054/Context-Engineering-for-Multi-Agent-Systems/blob/main/sovereign_ai/DeepSeek%E2%80%91R1_Sovereign_AI_Guide_Triton_Kernel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **DeepSeek‑R1 Sovereign AI Guide**
# *Implementing the Open‑Source DeepSeek‑R1‑Distill‑Llama‑8B Model* with Triton kernel.
#
# 📌 **Copyright 2025-2026, Denis Rothman**

# %% [markdown]
# # **🌍 Why Open‑Source LLMs Enable Sovereign, Strategic AI**
#
# Using an open‑source model such as **_DeepSeek‑R1‑Distill‑Llama‑8B_** gives organizations full **_sovereignty_** over their AI infrastructure. Because the model runs entirely on hardware you control—whether in Google Drive, a local workstation, or a private cloud—every prompt, dataset, and output remains **_inside your own environment_**. This eliminates reliance on external APIs and ensures that sensitive information never leaves your secured systems.
#
# Open‑source deployment also provides **_long‑term independence_** for strategic projects. You are free to customize, optimize, fine‑tune, or extend the model without vendor lock‑in, usage limits, or unpredictable pricing changes. This level of autonomy is essential for government agencies, research institutions, and enterprises that require stable, transparent, and fully auditable AI behavior.
#
# Finally, models like **_DeepSeek‑R1_** support **_regulatory compliance_** and **_data‑governance requirements_** by allowing teams to enforce their own security policies end‑to‑end. Whether the goal is confidential R&D, legal analysis, industrial planning, or national‑level digital sovereignty, open‑source LLMs offer a robust foundation for building trustworthy, mission‑critical AI systems.

# %% [markdown]
# **Motivation** This notebook serves as a **Sovereign AI Proof of Concept**. It demonstrates how to deploy a high-reasoning, open-source model, in this case,  **DeepSeek-R1-Distill-Llama-8B**, in a fully controlled environment. By running this locally, organizations ensure that strategic data never leaves their infrastructure, fulfilling the requirements for *mission-critical and regulated industries*.

# %% [markdown]
# # **🚀 Installing and running DeepSeek-R1-Distill-Llama-8B**
#
# This notebook provides a **step-by-step guide** on how to **download and run DeepSeek-R1-Distill-Llama-8B** locally in **Google Drive**.  The version downloaded is an open-source distilled version of DeepSeek-R1 provided by  unsloth, an LLM accelerator,  on Hugging Face :https://unsloth.ai/
#
# If you don't want to use Google Drive, you can install the artefacts on a local machine, server or cloud server.
#
# ### **🔹 How to Get Started**
# 1️⃣ **Install the model's artifacts** → Set `install_deepseek=True` and run all cells.
# 2️⃣ **Restart the session** → Disconnect and start a new session.
# 3️⃣ **Re-run the model** → Set `install_deepseek=False` and run all cells again.
# 4️⃣ **Interact with the model** → Use it in a prompt session!
#
# ⚠️ **System Requirements**
# ✅ **GPU** – Minimum **16GB** VRAM required.
# ✅ **Google Drive Space** – At least **20GB** free space.
# 📌 **Educational Use Only** – For production, deploy artifacts on a **local or cloud server**.
#
# ---
#
# ## **📖 Table of Contents**
#
# ### **1️⃣ Setting Up the DeepSeek Environment (Hugging Face)**
# ✅ Checking GPU Activation
# 📂 Mounting Google Drive
# ⚙️ Installing the Hugging Face Environment
# 🔄 Ensuring `install_deepseek=True` for First Run
# 📌 Checking Transformer Version
#
# ### **2️⃣ Downloading DeepSeek-R1-Distill-Llama-8B**
# 📂 Verifying Download Path
#
# ### **3️⃣ Running a DeepSeek Session**
# 🔄 Setting `install_deepseek=False` for Second Run
# 📌 Model Information
# 💬 Running an Interactive Prompt Session
#
# ---
#
# ### **💡 Ready to Use DeepSeek?**
# Follow the **installation steps**, ensure you have the required **hardware**, and launch your **interactive AI session** 🚀

# %% [markdown]
# This notebook was developed in Google Colab. Colab includes many pre-installed libraries and sets `/content/` as the default directory, meaning you can access files directly by their filename if you wish (e.g., `filename` instead of needing to specify `/content/filename`). This differs from local environments, where you'll often need to install libraries or specify full file paths.

# %% [markdown]
# # 1. Setting up DeepSeek Hugging Face environment

# %% [markdown]
# Set the *installation toggle*. Use `True` for the initial setup to download artifacts to your persistent storage (e.g., Google Drive), and `False` for subsequent inference sessions.

# %%
# Set install_deepseek to True to download and install R1 Distill Llama 8B locally
# Set install_deepseek to False to run an R1 session
install_deepseek=False

# %% [markdown]
# ## Checking GPU activation

# %% [markdown]
# Verify the hardware accelerator. For industrial-grade performance in *seconds*, not *minutes*, this notebook is optimized for **NVIDIA H100(Hopper architecture)** with **HBM3(High Bandwidth Memory 3)** is the third generation of ultra‑high‑speed stacked memory used in advanced GPUs and AI accelerators.
#
# The following command confirms the available `VRAM` and driver status.

# %%
# !nvidia-smi

# %% [markdown]
# ## Mount Google Drive

# %% [markdown]
# Mount persistent storage to maintain a local `model bank`. This prevents the need to re-download the *8B parameter model* (approx. 15GB-20GB) in every new session.

# %%
import os
from google.colab import drive

if os.path.ismount('/content/drive'):
    print(f"✅ Google Drive already mounted — skipping.")
    print(f"   Session cache active.")
else:
    print(f"📂 Mounting Google Drive...")
    drive.mount('/content/drive')
    print(f"✅ Google Drive mounted successfully.")

# Final verification
print(f"📍 Drive path: /content/drive/MyDrive")

# %% [markdown]
# Redirect the Hugging Face cache to your mounted storage. This ensures the model shards are retrieved from your private environment, maintaining architectural sovereignty.

# %%
import os

# Define the cache directory in your Google Drive
cache_dir = '/content/drive/MyDrive/genaisys/HuggingFaceCache'

# Set environment variables to direct Hugging Face to use this cache directory
os.environ['TRANSFORMERS_CACHE'] = cache_dir

# %% [markdown]
# ## Installation Hugging Face environment

# %% [markdown]
# Install the specific version of the *Transformers library* required for *DeepSeek-R1* compatibility. This ensures stability across different cloud or local environments.

# %%
import subprocess
import sys
import importlib

def get_transformers_version():
    try:
        import transformers
        return transformers.__version__
    except ImportError:
        return None

current_version = get_transformers_version()

if current_version is not None:
    print(f"✅ transformers v{current_version} already installed — skipping.")
    print(f"   Session cache active.")
else:
    print(f"⚙️  transformers not found. Installing latest version...")

    subprocess.run(
        [sys.executable, "-m", "pip", "install", "transformers"],
        check=True
    )
    print(f"✅ transformers installed successfully.")

# Final verification
import transformers
importlib.reload(transformers)
print(f"⚡ transformers v{transformers.__version__} ready.")

# %% [markdown]
# # 2.DeepSeek download

# %% [markdown]
# Initialize the model loading sequence. We use `device_map=auto `to optimize memory distribution across the H100’s HBM3 memory. On SOTA hardware, this setup enables the model to remain resident in VRAM for near-instant response.

# %% [markdown]
# ## ⚡ Flash Attention 2: The Triton Kernel for Attention
#
# Standard attention computes the full (seq_len × seq_len) score matrix
# and writes it to HBM before computing the softmax. At 131K tokens this
# is a catastrophic memory cost:
#
#     131,072 × 131,072 × 2 bytes (bfloat16) = ~34 GB
#     just for a single attention layer's intermediate matrix.
#
# Flash Attention 2 eliminates this entirely using the same architectural
# philosophy as the Triton Planner Kernel:
#
# | Triton Planner Kernel       | Flash Attention 2              |
# |-----------------------------|--------------------------------|
# | Load events into SRAM once  | Load Q,K,V tiles into SRAM     |
# | Atomic operations in-register| Softmax computed in-register  |
# | Single write-back to HBM    | Single write-back to HBM       |
# | No intermediate materialization | No score matrix in HBM    |
#
# The result is that attention memory cost drops from O(seq_len²) to
# O(seq_len) — the quadratic wall that makes long-context inference
# prohibitively expensive on standard kernels is removed entirely.
#
# On the H100 with bfloat16, Flash Attention 2 typically delivers
# 2-4x faster attention computation and uses 5-20x less VRAM for
# long sequences compared to the HuggingFace default path.
#
# This is not an approximation. The outputs are mathematically
# identical to standard attention — only the execution path changes.
# The DeepSeek weights and reasoning behavior are completely unaffected.

# %%
import subprocess
import sys
import os
import importlib

# --- CONFIGURATION ---
# Same Google Drive structure as your DeepSeek checkpoint
flash_attn_cache = '/content/drive/MyDrive/genaisys/flash_attn_cache'
os.makedirs(flash_attn_cache, exist_ok=True)

def get_flash_attn_version():
    try:
        import flash_attn
        return flash_attn.__version__
    except ImportError:
        return None

current_version = get_flash_attn_version()

if current_version is not None:
    print(f"✅ Flash Attention v{current_version} already active — skipping.")

else:
    # --- CHECK GOOGLE DRIVE FIRST ---
    # If the wheel was previously saved, install from Drive
    # instead of recompiling — instant install
    saved_wheels = [f for f in os.listdir(flash_attn_cache)
                    if f.endswith('.whl')] if os.path.exists(flash_attn_cache) else []

    if saved_wheels:
        # Use the most recently saved wheel
        wheel_path = os.path.join(flash_attn_cache, sorted(saved_wheels)[-1])
        print(f"📂 Found saved wheel in Google Drive: {saved_wheels[-1]}")
        print(f"⚙️  Installing from Drive (no recompilation)...")

        subprocess.run(
            [sys.executable, "-m", "pip", "install", wheel_path],
            check=True
        )
        print(f"✅ Flash Attention installed from Drive cache.")

    else:
        # --- FIRST TIME: COMPILE FROM SOURCE AND SAVE TO DRIVE ---
        print(f"⚙️  No saved wheel found. Compiling from source...")
        print(f"⏱️  Expected time: 5-15 minutes (CPU-bound nvcc compilation)")
        print(f"☕ This only happens once — wheel will be saved to Google Drive.")

        # Compile and install
        subprocess.run(
            [sys.executable, "-m", "pip", "install",
             "flash-attn", "--no-build-isolation"],
            check=True
        )

        # --- SAVE THE COMPILED WHEEL TO GOOGLE DRIVE ---
        print(f"\n💾 Saving compiled wheel to Google Drive...")

        subprocess.run(
            [sys.executable, "-m", "pip", "download",
             "flash-attn",
             "--no-build-isolation",
             "--no-deps",
             "-d", flash_attn_cache],
            check=True
        )

        saved = os.listdir(flash_attn_cache)
        print(f"✅ Wheel saved to: {flash_attn_cache}")
        print(f"📦 Files: {saved}")
        print(f"🔁 Next session: installs in seconds from Drive.")

# --- FINAL VERIFICATION ---
importlib.invalidate_caches()
import flash_attn
print(f"\n⚡ Flash Attention v{flash_attn.__version__} ready.")

# %% [markdown]
# Flash Attention is not a pre-compiled package — **it compiles C++ and CUDA code from source on your machine during installation**.
#
# When you run:
# ```
# pip install flash-attn --no-build-isolation
# ```
#
# What actually happens is:
#
# ```
# Download source code
#         ↓
# C++ compiler runs        (~30 seconds)
#         ↓
# CUDA compiler (nvcc) runs for EACH GPU kernel    ← this is the slow part
#         ↓
# Kernels compiled for your specific architecture (Blackwell sm_100)
#         ↓
# Package linked and installed
# ```
#
# The CUDA compilation step is the wall. Flash Attention contains dozens of hand-optimized CUDA kernels — one for each combination of head dimension, sequence length, and precision (bfloat16, float16, float32). Every single one gets compiled by `nvcc` individually.
#
# **Why not just ship pre-compiled binaries?**
#
# The Flash Attention team would need to pre-compile for every combination of:
#
# | Variable | Options |
# |---|---|
# | CUDA version | 11.x, 12.x, 13.x |
# | GPU architecture | Ampere, Hopper, Ada, Blackwell |
# | Python version | 3.9, 3.10, 3.11, 3.12 |
# | PyTorch version | 2.0, 2.1, 2.2, 2.3, 2.4, 2.5 |
#
# That's hundreds of binary combinations to maintain. Compiling locally sidesteps this entirely — your machine produces exactly the right binary for your exact environment in one shot.
#
# On your Blackwell RTX PRO 6000 specifically it takes longer than older cards because Blackwell (`sm_100`) is a newer architecture target that nvcc has more work to do optimizing for.

# %%
import subprocess
import sys

def get_triton_version():
    try:
        import triton
        return triton.__version__
    except ImportError:
        return None

current_version = get_triton_version()

if current_version is not None:
    print(f"✅ Triton v{current_version} already installed — skipping.")
    print(f"   Session cache active.")
else:
    print(f"⚙️  Triton not found. Installing...")
    subprocess.run(
        [sys.executable, "-m", "pip", "install", "triton"],
        check=True
    )
    print(f"✅ Triton installed successfully.")

# Final verification
import importlib
import triton
importlib.reload(triton)
print(f"⚡ Triton v{triton.__version__} ready.")

# %% [markdown]
# The reason this cell is the right starting point comes directly from your Triton Planner work. In your planner, the kernel launch was the bottleneck — everything else (RAM audit, tensor allocation, visualization) was negligible by comparison.
#
# The inference cell is the exact equivalent: everything else in your DeepSeek notebook — mounting Drive, loading weights, tokenizing — is a one-time or negligible cost.
#
# The model.generate() loop is where the silicon is being under-utilized.
#
# What Each Change Does
# torch.backends.cuda.enable_flash_sdp(True) forces the attention computation through Flash Attention, which is structurally identical to your fused kernel philosophy — it loads Q, K, V into SRAM once and never writes intermediate attention scores back to HBM.
#
# On H100 with bfloat16 at your context length, this eliminates the dominant memory bandwidth cost.
#
# torch.compile with inductor backend is the practical equivalent of what you did manually in Triton for the planner. Instead of writing the kernel yourself, Inductor analyzes the 32-layer forward pass and generates fused Triton kernels automatically — collapsing operations that HuggingFace executes as separate CUDA calls into single kernel launches.
# torch.inference_mode() is a harder version of torch.no_grad(). It disables the autograd graph entirely, freeing both memory and compute that gradient tracking consumes even during inference.
# Expected Results on Your H100
#
# MetricBaselineWith TritonInference time9.75s~3-5sTokens/sec~51~100-160VRAM peakhigherlowerGPU utilizationpartialcloser to 100%
#
# The compilation step will take 60-120 seconds the first time — this is the JIT cost equivalent to Triton's warm-up in your planner. After that first run, the compiled kernels are cached and subsequent calls pay only the inference cost.what cell does it replace?17:29It replaces this cell.
#
# The Key Addition: attn_implementation="flash_attention_2"
# This is the critical line. It tells HuggingFace to wire Flash Attention 2 directly into the model architecture at load time, rather than injecting it later. This means by the time your inference cell runs, the attention mechanism is already pointing at the optimized kernel. The two cells work together as a pipeline:
#
# | **Load cell**                 | **Inference cell**                     |
# |------------------------------|-----------------------------------------|
# | `attn_implementation=FA2`    | `torch.compile` locks it in             |
# | `device_map={"": 0}`         | no device transfers during `generate()` |
# | `model.eval()`               | `torch.compile(fullgraph=True)` cleaner |
# | bfloat16 explicit            | tensor cores fully utilized             |

# %% [markdown]
# The guard mechanism is model._triton_compiled = True — a flag branded directly onto the model object. Since the model lives in session memory, this flag survives across cell re-runs for the entire session lifetime. The moment the session resets or the model is reloaded, the flag disappears and compilation runs exactly once again automatically.

# %% [markdown]
# Audit the local file system to confirm all model shards and snapshots have been correctly saved to your *sovereign storage.*

# %%
if install_deepseek==True:
 # !ls -R /content/drive/MyDrive/genaisys/HuggingFaceCache

# %% [markdown]
# # 3.DeepSeek-R1-Distill-Llama-8B session

# %% [markdown]
# ## Loading the model

# %% [markdown]
# Prepare the inference session. By setting `local_files_only=True`, we guarantee that the system is operating in a disconnected, sovereign mode with no external calls to Hugging Face during execution.

# %% [markdown]
# The Key Addition: attn_implementation="flash_attention_2"
# This is the critical line. It tells HuggingFace to wire Flash Attention 2 directly into the model architecture at load time, rather than injecting it later. This means by the time your inference cell runs, the attention mechanism is already pointing at the optimized kernel. The two cells work together as a pipeline:
# Load cell                    Inference cell
# ─────────────────────────    ──────────────────────────
# attn_implementation=FA2  →   torch.compile locks it in
# device_map={"": 0}       →   no device transfers during generate()
# model.eval()             →   torch.compile fullgraph is cleaner
# bfloat16 explicit        →   tensor cores fully utilized
# One Prerequisite
# Flash Attention 2 requires a separate install. Add this as a new cell immediately before the model loading cell:

# %%
import time
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM

if install_deepseek == False:

    model_path = '/content/drive/MyDrive/genaisys/HuggingFaceCache/models--unsloth--DeepSeek-R1-Distill-Llama-8B/snapshots/71f34f954141d22ccdad72a2e3927dddf702c9de'

    # --- LOAD ONCE PER SESSION ---
    # Re-loading an 8B model costs ~15-20 seconds and re-allocates
    # the full VRAM footprint. The flag prevents this on cell re-runs.
    if 'model' not in dir() or not getattr(model, '_loaded', False):
        print("📂 Loading model into H100 VRAM (one-time per session)...")
        start_time = time.time()

        tokenizer = AutoTokenizer.from_pretrained(
            model_path,
            local_files_only=True
        )

        model = AutoModelForCausalLM.from_pretrained(
            model_path,
            local_files_only=True,
            torch_dtype=torch.bfloat16,
            device_map={"": 0},
            attn_implementation="flash_attention_2"
        )

        # Lock to eval mode — disables dropout, batch norm tracking
        # Required before torch.compile in the inference cell
        model.eval()

        # Brand the model object — survives cell re-runs
        # disappears only when session resets
        model._loaded = True

        end_time = time.time()
        elapsed_time = end_time - start_time

        # Telemetry
        vram_used = torch.cuda.memory_allocated(0) / 1e9
        vram_total = torch.cuda.get_device_properties(0).total_memory / 1e9

        print(f"\n📊 MODEL LOAD AUDIT")
        print(f"-" * 45)
        print(f"⏱️  Load Time:          {elapsed_time:.2f} seconds")
        print(f"🧠 VRAM Used:          {vram_used:.2f} GB / {vram_total:.2f} GB")
        print(f"⚡ Precision:          bfloat16 (H100 tensor cores)")
        print(f"🔒 Attention:          Flash Attention 2")
        print(f"📍 Device:             GPU 0 (single device, no offload)")
        print(f"-" * 45)

    else:
        vram_used = torch.cuda.memory_allocated(0) / 1e9
        vram_total = torch.cuda.get_device_properties(0).total_memory / 1e9
        print(f"✅ Model already loaded — skipping (session cache active).")
        print(f"-" * 45)
        print(f"🧠 VRAM Active:        {vram_used:.2f} GB / {vram_total:.2f} GB")
        print(f"-" * 45)

# %% [markdown]
# The guard uses 'model' not in dir() as the first check — this handles the cold start where the variable doesn't exist yet. The second check not getattr(model, '_loaded', False) handles the re-run case where model exists but points to something other than your loaded DeepSeek instance. Both conditions must fail before the load is skipped, making the guard robust against all re-run scenarios within the same session.

# %% [markdown]
# Review the model configuration. Note the max_position_embeddings and `torch_dtype`. On `H100`, we utilize bfloat16 to maximize throughput without sacrificing reasoning precision.

# %%
if install_deepseek==False:
  print(model.config)

# %% [markdown]
# ## Prompts

# %% [markdown]
# Define complex, domain-specific prompts (Legal and Industrial).
#
# These prompts include Strict Output Rules to test the model's ability to follow architectural constraints.

# %%
if install_deepseek==False:
  prompt1 = """
Provide a clear, concise, and professional explanation of how a product designer can turn customer requirements for a traveling bag into a practical production plan.

Strict Output Rules:
- Do not show internal reasoning, chain-of-thought, or hidden thinking.
- Do not describe what you are doing.
- Do not restate or reflect on the instructions.
- Do not explain your approach.
- Do not comment on the task.
- Do not use filler phrases such as “Alright, so the user wants…”.
- Do not switch languages.
- Output only the final answer in clean English.
- Use bullet points only.
- Each bullet point must be a single factual statement.
- If you begin to generate internal reasoning, stop immediately and output only the final answer.
"""
  prompt2= """
Provide a clear, concise, and professional explanation of how a legal advisor should create a plan to defend a copyright issue in court.

Strict Output Rules:
- Do not show internal reasoning, chain-of-thought, or hidden thinking.
- Do not describe what you are doing.
- Do not restate or reflect on the instructions.
- Do not explain your approach.
- Do not comment on the task.
- Do not use filler phrases such as “Alright, so the user wants…”.
- Do not switch languages.
- Output only the final answer in clean English.
- Use bullet points only.
- Each bullet point must be a single factual statement.
- If you begin to generate internal reasoning, stop immediately and output only the final answer.
"""

# %% [markdown]
# Execute the inference. Benchmark Note: On the NVIDIA H100, this 8B reasoning model achieves inference in about 10 seconds (approx. 9.75s) for complex multi-step tasks. This proves that open-source sovereign AI can match the responsiveness of proprietary cloud APIs.

# %% [markdown]
# Display the final response. This output represents the **Glass-Box** results: a factual, structured production or legal plan generated entirely within a secure, sovereign environment.

# %%
# ============================================================
# CELL: Triton-Accelerated Inference
# DeepSeek weights unchanged — only the execution engine upgrades
# ============================================================

import time
import torch
import triton
from torch.nn.attention import SDPBackend, sdpa_kernel

if install_deepseek == False:

    # --- STEP 1: Flash Attention backend flags ---
    torch.backends.cuda.enable_flash_sdp(True)
    torch.backends.cuda.enable_math_sdp(False)
    torch.backends.cuda.enable_mem_efficient_sdp(False)

    # --- STEP 2: Compile ONCE per session ---
    if not getattr(model, '_triton_compiled', False):
        print("🔥 Compiling model with Triton backend (one-time JIT)...")
        compile_start = time.time()

        model = torch.compile(
            model,
            backend="inductor",
            mode="max-autotune",   # Blackwell: finds optimal kernel config
            fullgraph=False
        )

        model._triton_compiled = True
        compile_time = time.time() - compile_start
        print(f"✅ torch.compile() wrap: {compile_time:.2f}s")

        # --- WARMUP: Forces Triton JIT to compile kernels NOW ---
        print(f"🔥 Warming up Triton kernels (JIT compilation)...")
        warmup_start = time.time()

        warmup_input = tokenizer("warmup", return_tensors='pt').to('cuda')
        with torch.inference_mode():
            with sdpa_kernel(SDPBackend.FLASH_ATTENTION):
                _ = model.generate(**warmup_input, max_new_tokens=1)

        torch.cuda.synchronize()
        warmup_time = time.time() - warmup_start
        print(f"✅ Triton JIT warmup complete: {warmup_time:.2f}s (one-time cost)")

    else:
        print("✅ Triton compilation already active — skipping.")

    # --- STEP 3: Inference — pure execution, no JIT cost ---
    print("\n🚀 Running Triton-accelerated inference...")
    start_time = time.time()

    inputs = tokenizer(prompt2, return_tensors='pt').to('cuda')

    with torch.inference_mode():
        with sdpa_kernel(SDPBackend.FLASH_ATTENTION):
            outputs = model.generate(
                **inputs,
                max_new_tokens=500,
                repetition_penalty=1.05,
                no_repeat_ngram_size=3,
                temperature=0.2,
                top_p=0.9,
                top_k=20,
                eos_token_id=tokenizer.eos_token_id,
                use_cache=True
            )

    torch.cuda.synchronize()
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # --- STEP 4: Telemetry ---
    elapsed_time = time.time() - start_time
    tokens_generated = outputs.shape[1] - inputs['input_ids'].shape[1]
    throughput = tokens_generated / elapsed_time

    print(f"\n📊 TRITON INFERENCE AUDIT")
    print(f"-" * 45)
    print(f"⏱️  Inference Time:     {elapsed_time:.2f} seconds")
    print(f"🚀 Tokens Generated:   {tokens_generated}")
    print(f"⚡ Throughput:         {throughput:.1f} tokens/sec")
    print(f"📉 Baseline (HF):      9.75 seconds")
    print(f"📈 Speedup:            {9.75/elapsed_time:.2f}x")
    print(f"-" * 45)

# %%
print(generated_text)

# %% [markdown]
# # 🔍 Deconstructing the Reasoning Output
#
# In this Proof of Concept run on an `NVIDIA H100`, we observe the raw output of the `DeepSeek-R1-Distill-Llama-8B` model. This output is composed of three distinct segments that require specific handling in a **Sovereign Context Engine**:
#
# **The Prompt Reflection (Post-Processing Required)**: Notice how the model initially restates the rules and its understanding of the legal task. In a production UI, this section is typically filtered out via string parsing or regex to maintain a professional interface.
#
# **The Reasoning Trace (The </think> Block)**: This is the 'Glass-Box' in action. The model explicitly weighs the steps of a copyright defense—from evidence gathering to expert testimony—before committing to a final answer. For Sovereign AI, this trace is your audit trail, providing 100% observability into how the AI reached its conclusion.
#
# **The Final Factual Output:** This is the clean, bulleted production plan the user requested. On the H100, this entire multi-stage cognitive process was completed in just 9.75 seconds, demonstrating that open-source models can deliver high-speed, verifiable results without external API dependencies.
#
# **Strategic Takeaway for Architects:**  When deploying this in a Multi-Agent System, your Orchestrator should be designed to capture the reasoning trace for your logs while delivering only the final cleaned text to the end-user. This ensures both operational transparency and a seamless user experience."
